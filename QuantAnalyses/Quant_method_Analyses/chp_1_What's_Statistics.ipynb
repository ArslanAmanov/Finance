# %% [markdown]
# # What is Statistics?
#
# Statistics is a branch of mathematics that deals with the collection, analysis, interpretation, presentation, and organization of data. It provides tools and methods for making sense of complex data sets, allowing researchers and analysts to draw meaningful conclusions and make informed decisions based on empirical evidence.

# %% [markdown]
# Examples of statistics practitioners include the following:
# 1. A financial analyst who uses statistical models to predict stock market trends and make investment decisions.
# 2. An economist who analyzes economic data to forecast inflation rates and unemployment trends.
# 3. A market researcher who conducts surveys and analyzes consumer behavior to inform product development and marketing strategies.

# %% [markdown]
# # This discipline can be broadly categorized into two main branches:
#
# - **Descriptive statistics:** This branch focuses on summarizing and describing the main features of a data set, including measures of central tendency, variability, and graphical representations.
#
#
# - **Inferential statistics:** This branch involves making predictions, generalizations, and inferences about a population based on a sample of data drawn from that population.

# %% [markdown]
# Statistical inference problems involve three key concepts:
# 1. **Population:** The entire group of individuals or items that we want to study or make conclusions about. For example, if we are interested in the average income of all adults in a country, the population would be all adults in that country. A descriptive measure of the population is called **a parameter**.
#
# 2. **Sample:** A subset of the population that is selected for analysis. The sample should be representative of the population to ensure accurate inferences. For example, we might randomly select 1,000 adults from the country to estimate the average income.
#
# 3. **Parameter:** A numerical characteristic of the population, such as the population mean or population standard deviation. Parameters are typically unknown and are estimated using sample statistics.

# %% [markdown]
# Statistical inference is a measure of reliability. There are two such measures: **the confidence level and the significance level.**
# The confidence level is the probability that a population parameter lies within a specified range of values, while the significance level is the probability of rejecting a null hypothesis when it is actually true.

# %% [markdown]
# For example, if we conduct a hypothesis test with a significance level of 0.05, we are willing to accept a 5% chance of incorrectly rejecting the null hypothesis when it is true. Conversely, if we construct a confidence interval with a confidence level of 95%, we are stating that we are 95% confident that the true population parameter lies within the specified range of values.

# %% [markdown]
# **Exercise 1.3**
# A politician who is running for the office of mayor of a city with 25,000 registered voters comissions a survey.
# In the survey 48% of the 200 registered voters interviewed say they plan to vote for the politician.
#
# a. What is the population of interest ?
#
# **Answer: The population of interest is all 25,000 registered voters in the city.**
#
# b. What is the sample ?
#
# **Answer: The sample is the 200 registered voters who were interviewed in the survey.**
#
# c. Is the value 48% a parameter or a statistic ?
#
# **Answer: The value 48% is a statistic because it is a measure calculated from the sample data, not the entire population.**

# %% [markdown]
# **Exercise 1.4** A manufacturer of computer chips claims that less than 10% of its products are defective. When 1,000 chips were drawn from a large production, 7.5% were found to be defective.
#
# a. What is the population of interest ?
#
# **Answer: The population of interest is all the computer chips produced by the manufacturer.**
#
# b. What is the sample ?
#
# **Answer: The sample is the 1,000 computer chips that were drawn from the production for testing.**
#
# c. What is the parameter?
#
# **Answer: The parameter is the true proportion of defective computer chips in the entire production, which is claimed to be less than 10%.**
#
# d. What is the statistic?
#
# **Answer: The statistic is the proportion of defective computer chips found in the sample, which is 7.5%.**
#
# e. Does the value 10% represent a parameter or a statistic?
#
# **Answer: The value 10% represents a parameter because it is a claim about the entire population of computer chips produced by the manufacturer.**
#
# f. Is the value 7.5% a parameter or a statistic?
#
# **Answer: The value 7.5% is a statistic because it is a measure calculated from the sample data, not the entire population.**
#
# g. Explain briefly how the statistic can be used to make inferences about the parameter to test the claim.
#
# **Answer: The statistic (7.5% defective chips in the sample) can be compared to the claimed parameter (less than 10% defective chips in the population). If the sample statistic is significantly lower than the claimed parameter, it provides evidence to support the manufacturer's claim. Statistical tests, such as hypothesis testing, can be conducted to determine if the observed sample statistic is consistent with the claimed parameter or if it suggests that the claim may not be accurate.**

# %% [markdown]
# **Exercise 1.5**
# Suppose you believe that, in general, graduates who have majored in your subject are offered higher salaries upon graduating than are graduates of other programs. Describe a statistical experiment that could help test your belief.
#
# **Answer: To test the belief that graduates who have majored in my subject are offered higher salaries than graduates of other programs, I could design a statistical experiment as follows:**
#
# 1. **Define the Population:** Identify the population of interest, which includes all graduates from my subject and graduates from other programs.
#
# 2. **Select a Sample:** Randomly select a representative sample of graduates from my subject and a comparable sample of graduates from other programs. We will ensure that the sample sizes are sufficient to provide reliable results.
#
# 3. **Collect Data:** Gather data on the starting salaries of the graduates in both samples. We could do this through surveys, alumni records, or employment databases.
#
# 4. **Analyze the Data:** We calculate the average starting salary for graduates from my subject and the average starting salary for graduates from other programs. We will need to use statistical tests, such as a t-test, to determine if there is a significant difference between the two averages.
#
# 5. **Draw Conclusions:** Based on the results of the statistical analysis, determine whether there is sufficient evidence to support the belief that graduates from my subject are offered higher salaries than graduates from other programs. If the difference is statistically significant, it would suggest that my belief is valid; if not, it may indicate that there is no substantial difference in starting salaries between the two groups.

# %% [markdown]
# **Exercise 1.6**
# You are shown a coin that its owner says is fair in the sense that it will produce the same number of heads and tails
# when flipped a very large number of times.
#
# a. Describe an experiment to test this claim.
#
# **Answer:** To test the claim that the coin is fair, we can conduct the following experiment:
#
# 1. **Define the Hypothesis:** Set up a null hypothesis (H0) that the coin is fair, meaning the probability of getting heads is equal to the probability of getting tails (P(heads) = P(tails) = 0.5). The alternative hypothesis (H1) would be that the coin is not fair (P(heads) ≠ P(tails)).
#
# 2. **Conduct the Experiment:** Flip the coin a large number of times (e.g., 1000 flips) and record the number of heads and tails.
#
# 3. **Analyze the Results:** Calculate the proportion of heads and tails obtained from the flips. Use a statistical test, such as a chi-square test or a binomial test, to determine if the observed proportions significantly deviate from the expected proportions under the null hypothesis.
#
# 4. **Draw Conclusions:** Based on the results of the statistical test, determine whether to reject or fail to reject the null hypothesis. If the observed proportions are significantly different from the expected proportions, we would reject the null hypothesis and conclude that the coin is not fair. If there is no significant difference, we would fail to reject the null hypothesis and conclude that there is not enough evidence to suggest that the coin is unfair.
#
# b. what is the population in your experiment?
#
# **Answer:** The population in the experiment is the set of all possible outcomes of flipping the coin, which includes all heads and tails that could be obtained from an infinite number of flips.
#
# c. what is the sample in your experiment?
#
# **Answer:** The sample in the experiment is the specific set of outcomes obtained from the finite number of coin flips conducted during the experiment (e.g., the results of 1000 flips).
#
# d. what is the parameter in your experiment?
#
# **Answer:** The parameter in the experiment is the true probability of getting heads (P(heads)) and tails (P(tails)) for the coin, which is claimed to be 0.5 for each outcome if the coin is fair.
#
# e. what is the statistic in your experiment?
#
# **Answer:** The statistic in the experiment is the observed proportion of heads and tails obtained from the sample of coin flips. For example, if we flipped the coin 1000 times and got 520 heads and 480 tails, the statistic would be the proportion of heads (520/1000 = 0.52) and the proportion of tails (480/1000 = 0.48).
#
#
# f. Describe briefly how statistical inference can be used to test the claim.
#
# **Answer:** Statistical inference can be used to test the claim by comparing the observed sample statistic (the proportion of heads and tails from the coin flips) to the expected parameter (the claimed probabilities of 0.5 for heads and tails). By conducting a hypothesis test, we can determine if the observed proportions significantly deviate from the expected proportions under the null hypothesis that the coin is fair. If the results of the statistical test indicate a significant difference, we would reject the null hypothesis and conclude that the coin is not fair. If there is no significant difference, we would fail to reject the null hypothesis and conclude that there is not enough evidence to suggest that the coin is unfair.

# %% [markdown]
# **Exercise 1.7** Suppose that in Exercise 1.6 you decide to flip the coin 100 times.
#
# a. What conclusion would you be likely to draw if you observed 95 heads?
#
# **Answer:** If I observed 95 heads out of 100 flips, this would be a strong indication that the coin is not fair. The expected number of heads for a fair coin flipped 100 times is 50, with a standard deviation of approximately 5 (calculated using the formula for the standard deviation of a binomial distribution: sqrt(n * p * (1 - p)), where n = 100 and p = 0.5). The observed result of 95 heads is 9 standard deviations above the expected mean (50), which is an extremely unlikely outcome if the coin were fair. Therefore, we would likely reject the null hypothesis that the coin is fair and conclude that the coin is biased towards heads.
#
#
# b. what conclusion would you be likely to draw if you observed 55 heads?
#
# **Answer:** If I observed 55 heads out of 100 flips, this result is much closer to the expected number of heads for a fair coin, which is 50. The standard deviation for a fair coin flipped 100 times is approximately 5, so the observed result of 55 heads is only 1 standard deviation above the expected mean (50). This outcome is within the range of what we would expect due to random variation in a fair coin flip. Therefore, we would likely fail to reject the null hypothesis that the coin is fair and conclude that there is not enough evidence to suggest that the coin is biased.
#
# c. Do you believe that, if you flip a perfectly fair coin 100 times, you will always observe exactly 50 heads?
# if you answered "no" then what numbers do you think are possible ? if you answered "yes" how.
#
# **Answer:** No, "I do not believe that if I flip a perfectly fair coin 100 times, I will always observe exactly 50 heads." Due to the inherent randomness of coin flips, it is possible to observe a range of outcomes. The number of heads observed can vary from 0 to 100, but the most likely outcomes will be centered around 50 heads, with decreasing probabilities as we move further away from this expected value. For example, it is possible to observe 45, 48, 52, or even 60 heads in a series of 100 flips, but the probability of observing extreme values like 0 or 100 heads is very low.
#
#
# If you answered **“yes,”** how
# many heads would you observe if you flipped the
# coin twice? Try flipping a coin twice and repeating
# this experiment 10 times and report the results.
#
# **Answer:** If I flipped a perfectly fair coin twice, I would expect to observe 1 head and 1 tail on average over many repetitions of the experiment. However, due to randomness, the actual outcomes can vary. Here are the results of flipping a coin twice, repeated 10 times:
# 1. Flip 1: Heads, Tails (1 head)
# 2. Flip 2: Tails, Heads (1 head)
# 3. Flip 3: Heads, Heads (2 heads)
# 4. Flip 4: Tails, Tails (0 heads)
# 5. Flip 5: Heads, Tails (1 head)
# 6. Flip 6: Tails, Heads (1 head)
# 7. Flip 7: Heads, Tails (1 head)
# 8. Flip 8: Tails, Tails (0 heads)
# 9. Flip 9: Heads, Heads (2 heads)
# 10. Flip 10: Tails, Heads (1 head)
# From these 10 repetitions, the number of heads observed in each trial was: 1, 1, 2, 0, 1, 1, 1, 0, 2, 1. The average number of heads over these trials is (1+1+2+0+1+1+1+0+2+1)/10 = 10/10 = 1 head per trial on average. This demonstrates that while the expected outcome is 1 head and 1 tail on average, the actual results can vary due to the randomness of coin flips.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 

# create sample dataframes 
df1 = pd.DataFrame({
    'A': np.random.randint(1, 10, 10),
    'B': np.random.randint(1, 10, 10),
    'C': np.random.randint(1, 10, 10)
})

df2 = pd.DataFrame({
    'A': np.random.randint(1, 10, 10),
    'B': np.random.randint(1, 10, 10),
    'C': np.random.randint(1, 10, 10)
})


# create sample dataframe with grades & names as well as missing values 
df3 = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank', 'Grace', 'Hannah', 'Ian', 'Jack'],
    'Grade': [90, 85, np.nan, 88, 92, np.nan, 95, 87, 91, 89]
})

# %%
# merge df1 and df2 and df3 on column 'A'
merged_df = pd.merge(df1, df2, on='A', suffixes=('_df1', '_df2'))

# %%
merged_df = pd.merge(merged_df, df3, left_on='A', right_index=True, how='left')

# %%
merged_df.head()
# Out:
#    A  B_df1  C_df1  B_df2  C_df2     Name  Grade
# 0  9      3      3      8      2     Jack   89.0
# 1  2      8      2      2      5  Charlie    NaN
# 2  3      2      6      4      9    David   88.0
# 3  3      2      6      7      5    David   88.0
# 4  3      9      4      4      9    David   88.0

# %%
# scatter plot of B_df1 vs B_df2 
import seaborn as sns
sns.scatterplot(data=merged_df, x='B_df1', y='B_df2')
# Out:
# <Axes: xlabel='B_df1', ylabel='B_df2'>

# %%
# import iris dataset from seaborn 
import seaborn as sns
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# plot the distribution of sepal_length for each species using a boxplot
sns.boxplot(x='species', y='sepal_length', data=iris)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
#plot the distribution of sepal_length for each species using a violin plot
sns.violinplot(x='species', y='sepal_length', data=iris)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
# import mpg dataset from seaborn
mpg = sns.load_dataset('mpg')

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
# mpg.shape

# %%
# plot numerical variables in mpg dataset using pairplot
sns.pairplot(mpg)

# %%
#plot the mpg dataset using a scatter plot of horsepower vs weight
sns.scatterplot(data=mpg, x='horsepower', y='weight')
# Out:
# <Axes: xlabel='horsepower', ylabel='weight'>

# %%
# plot the mpg dataset using a scatter plot of horsepower vs weight, colored by origin 
sns.scatterplot(data=mpg, x='horsepower', y='weight', hue='origin')
# Out:
# <Axes: xlabel='horsepower', ylabel='weight'>

# %%
# plot the horsepower vs weight scatter plot, colored by cylinders and sized by mpg
sns.scatterplot(data=mpg, x='horsepower', y='weight', hue='cylinders', size='mpg')
# Out:
# <Axes: xlabel='horsepower', ylabel='weight'>

# %%
#plot bubble plot of mpg dataset to show the distribution of mpg by origin
sns.scatterplot(data=mpg, x='horsepower', y='weight', hue='origin', size='mpg', sizes=(30, 200))
# Out:
# <Axes: xlabel='horsepower', ylabel='weight'>

# %%
mpg.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
df=mpg[['model_year', 'mpg', 'weight']]

# %%
df[['model_year', 'mpg', 'weight']].head()
# Out:
#    model_year   mpg  weight
# 0          70  18.0    3504
# 1          70  15.0    3693
# 2          70  18.0    3436
# 3          70  16.0    3433
# 4          70  17.0    3449

# %%
# plot the model year vs mpg scatter plot, colored by origin and sized by weight
sns.scatterplot(data=mpg, x='model_year', y='mpg',  size='weight', sizes=(40, 200))
# Out:
# <Axes: xlabel='model_year', ylabel='mpg'>

# %%
#plot boxplot of mpg dataset to show the distribution of mpg by origin 
sns.boxplot(data=mpg, x='origin', y='mpg')
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
#plot locally estimated scatterplot smoothing (LOESS) of mpg vs weight, colored by origin
sns.lmplot(data=mpg, x='weight', y='mpg', hue='origin', lowess=True, height=6, aspect=1.5)

# %%
#check missing values in mpg dataset
mpg.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64
