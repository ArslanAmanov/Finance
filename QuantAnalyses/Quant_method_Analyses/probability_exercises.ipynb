# %% [markdown]
# # Problem solving 08/16/2026

# %%
from IPython.display import Image
Image(filename='exercise 7.7.png', width=800, height=800)

# %%
from IPython.display import Image
Image(filename='exercise 7.8.png', width=800, height=800)

# %%
from IPython.display import Image
Image(filename='exercise 7.20.png', width=800, height=800)

# %%
from IPython.display import Image
Image(filename='exercise 7.49.png', width=800, height=800)

# %%
from IPython.display import Image
Image(filename='exercise 7.49.1.png', width=800, height=800)

# %%
from IPython.display import Image
Image(filename='exercise 7.51.png', width=800, height=800)

# %% [markdown]
# # exercise 6.32
# A department store analyzed its most recent sales
# and determined the relationship between the
# way the customer paid for the item and the price category of the item.
# The joint probabilities in the following table were calculated.

# %%
from IPython.display import Image
Image(filename='exercise 6.32.png', width=800, height=800)

# %%
from IPython.display import Image
Image(filename='exercise 6.33.png', width=800, height=800)

# %%
from IPython.display import Image
Image(filename='exercise 6.34.png', width=800, height=800)

# %%
from IPython.display import Image
Image(filename='exercise 6.37.png', width=800, height=800)

# %%
from IPython.display import Image
Image(filename='exercise 6.39.png', width=800, height=800)

# %%
from IPython.display import Image
Image(filename='exercise 6.64.png', width=800, height=800)

# %%
from IPython.display import Image
Image(filename='exercise 6.68.png', width=800, height=800)
