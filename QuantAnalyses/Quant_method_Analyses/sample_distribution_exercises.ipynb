# %% [markdown]
# # Problem Solving  08/30/2026 - TA session

# %%
from pathlib import Path
from IPython.display import Image

image_relative_path = Path('Finance/QuantAnalyses/Quant_method_Analyses/file_png/exercise 9.18.png')
search_directories = [Path.cwd(), *Path.cwd().parents]
path = next(
    directory / image_relative_path
    for directory in search_directories
    if (directory / image_relative_path).is_file()
)
Image(filename=str(path), width=800, height=800)

# %%
from pathlib import Path
from IPython.display import Image

image_relative_path = Path('Finance/QuantAnalyses/Quant_method_Analyses/file_png/exercise 9.23.png')
search_directories = [Path.cwd(), *Path.cwd().parents]
path = next(
    directory / image_relative_path
    for directory in search_directories
    if (directory / image_relative_path).is_file()
)
Image(filename=str(path), width=800, height=800)

# %%
from pathlib import Path
from IPython.display import Image

image_relative_path = Path('Finance/QuantAnalyses/Quant_method_Analyses/file_png/exercise 9.30.png')
search_directories = [Path.cwd(), *Path.cwd().parents]
path = next(
    directory / image_relative_path
    for directory in search_directories
    if (directory / image_relative_path).is_file()
)
Image(filename=str(path), width=800, height=800)

# %%
from pathlib import Path
from IPython.display import Image

image_relative_path = Path('Finance/QuantAnalyses/Quant_method_Analyses/file_png/exercise 11.7.png')
search_directories = [Path.cwd(), *Path.cwd().parents]
path = next(
    directory / image_relative_path
    for directory in search_directories
    if (directory / image_relative_path).is_file()
)
Image(filename=str(path), width=800, height=800)

# %%
from pathlib import Path
from IPython.display import Image

image_relative_path = Path('Finance/QuantAnalyses/Quant_method_Analyses/file_png/exercise 11.36.png')
search_directories = [Path.cwd(), *Path.cwd().parents]
path = next(
    directory / image_relative_path
    for directory in search_directories
    if (directory / image_relative_path).is_file()
)
Image(filename=str(path), width=800, height=800)

# %%
from pathlib import Path
from IPython.display import Image

image_relative_path = Path('Finance/QuantAnalyses/Quant_method_Analyses/file_png/exercise 11.38.png')
search_directories = [Path.cwd(), *Path.cwd().parents]
path = next(
    directory / image_relative_path
    for directory in search_directories
    if (directory / image_relative_path).is_file()
)
Image(filename=str(path), width=800, height=800)
